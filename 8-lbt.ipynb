# %%
# %matplotlib widget
import warnings
import inspect
import matplotlib.pyplot as plt
import IPython.display
import numpy as np
from cued_sf2_lab.familiarisation import load_mat_img, plot_image
from cued_sf2_lab.dct import colxfm

# %% [markdown]
# # 8 The Lapped Bi-orthogonal Transform (LBT)
#
# <!-- sorry for the nasty HTML, markdown is bad for figures -->
#
# <figure style="text-align: center">
# <div class="row">
# <figure class="col-md-4 col-md-offset-1">
# <img src="figures/lbt.png" style="max-height: 350px" />
# <figcaption>(a) Lapped Bi-orthogonal Transform</figcaption>
# </figure>
#
# <figure class="col-md-5 col-md-offset-1">
# <img src="figures/pot.png" style="max-height: 350px" />
# <figcaption>(b) Photo Overlap Transform and a DCT</figcaption>
# </figure>
# </div>
# <div class="row">
# <figcaption>
# <br />
#
# Figure 4: (a) An LBT transforms overlapping sections of `X` to create `Y`. (b) In some cases
# this can be interpreted as pre-filtering with a POT, followed by a DCT.</figcaption></div></figure>

# %% [markdown]
# One of the difficulties with the DCT is that it processes each block separately and hence
# does not take advantage of any correlation between blocks. A possible solution to this is
# to use a _Lapped Bi-orthogonal Transform (LBT)_. These transform overlapping blocks in `X`
# to generate smaller non-overlapping blocks in `Y`. In the left-hand figure above, 16 values
# in `X` are used to generate each set of 8 values in `Y`.
#
# LBTs are quite complicated to derive and analyse: however one of the most popular forms<sup>3</sup>
# can also be represented as a pre-filtering operation before performing the DCT described
# in the previous section.
# In this case the pre-filtering (or post-filtering for the reverse
# operation) is sometimes known as a _Photo Overlap Transform or POT_. A POT followed
# by a DCT is then equivalent to a particular type of LBT.
#
# The right-hand figure above demonstrates this. The POT is first performed on a section
# of data `X`, shifted by `N/2`, so that it runs across the block boundaries of the subsequent
# DCT. Ignoring this block shift for a moment, the forward operation for a 2D image `X` is:
#
#
# $$Y = C ∗ Pf ∗ X ∗ Pf ′ ∗ C′$$
#
# or in reverse
#
# $$ X = Pr′ ∗ C′ ∗ Y ∗ C ∗ Pr $$
#
# <hr />
# <small><sup>3</sup>The type-II fast lapped (bi-)orthogonal transform, or LOT-II</small>

# %% [markdown]
# ## 8.1 Applying the LBT to images

# %%
X, cmaps_dict = load_mat_img(img='lighthouse.mat', img_info='X', cmap_info={'map', 'map2'})
X = X - 128.0

# %% [markdown]
# The pre-filtering `Pf ∗ X ∗ Pf′` (with the correct block shift) is straightforward in Python:
#
# ```python
# t = np.s_[N//2:-N//2]  # N is the DCT size, I is the image size
# Xp = X.copy()  # copy the non-transformed edges directly from X
# Xp[t,:] = colxfm(Xp[t,:], Pf)
# Xp[:,t] = colxfm(Xp[:,t].T, Pf).T
# ```

# %% [markdown]
# This is followed by the DCT `C` as before. In the reverse operation, the inverse DCT `C’` is
# performed first, followed by Pr’:
# ```python
# Zp = Z.copy()  #copy the non-transformed edges directly from Z
# Zp[:,t] = colxfm(Zp[:,t].T, Pr.T).T
# Zp[t,:] = colxfm(Zp[t,:], Pr.T)
# ```

# %% [markdown]
# We have provided a function `pot_ii(N, s)` which will generate a forward (pre-filtering,
# `Pf`) and reverse (post-filtering, `Pr`) matrix of size `N` with scaling factor `s`.

# %%
from cued_sf2_lab.lbt import pot_ii

# %% [markdown]
# Edit your code
# for performing DCT analysis so that it can pre-filter `X` with `Pf` before the forward DCT,
# then post-filter `Z` with `Pr` after the inverse DCT. Confirm that, without quantisation, this
# correctly recreates the original image, i.e. `Zp = X`. Use `Pf, Pr = pot_ii(N)` with the
# default scaling value `s`.

# %%
from cued_sf2_lab.laplacian_pyramid import bpp

def dctbpp(Yr, N): #calculate total bits from regrouped image
    h=Yr.shape[0]
    w=Yr.shape[1]
    block_h=int(h/N)
    block_w=int(w/N)

    total_bits = 0

    for i in range(N):
        for j in range(N):
            block = Yr[i*block_h:(i+1)*block_h, j*block_w:(j+1)*block_w]
            total_bits = total_bits + bpp(block)*block_h*block_w
            # block_sums[i, j] = np.sum(block)

    return total_bits

# %%
from cued_sf2_lab.dct import dct_ii
from cued_sf2_lab.laplacian_pyramid import quantise
from cued_sf2_lab.dct import regroup

# your code here

N=8

Pf, Pr = pot_ii(N)

t = np.s_[N//2:-N//2]  # N is the DCT size, I is the image size
Xp = X.copy()  # copy the non-transformed edges directly from X
Xp[t,:] = colxfm(Xp[t,:], Pf)
Xp[:,t] = colxfm(Xp[:,t].T, Pf).T


Xq = quantise(X,17)
X_q_total_bits = bpp(quantise(X,17))*X.shape[0]*X.shape[1]


C8 = dct_ii(8)

Y = colxfm(colxfm(Xp, C8).T, C8).T

N = 8

# def f(step_size):
#     Z = colxfm(colxfm(quantise(Y, step_size).T, C8.T).T, C8.T)
#     return abs(np.std(X-Xq)-np.std(X-Z))

# decimal_range = np.arange(0, 40, 0.1)
# optimal_step = -1
# smallest_diff = 10e15

# for i in decimal_range:
#     # print(i,"             ",abs(f(i)))
#     if f(i) < smallest_diff:
#         smallest_diff = f(i)
#         optimal_step = i

# print("optimal_step",optimal_step)
# Y_q = quantise(Y,optimal_step)


# Yr=regroup(Y_q, N)/N  #Yr is from quantised
# print("total bits using dctbpp",dctbpp(Yr,N))

# compression_ratio = X_q_total_bits/(dctbpp(Yr,N)) #Yr is quantised. this is variable coding N=4 here
# print("compression ratio",compression_ratio)

# Z = colxfm(colxfm(Y_q.T, C8.T).T, C8.T)
Z = colxfm(colxfm(Y.T, C8.T).T, C8.T) #dont quantise for now



Zp = Z.copy()  #copy the non-transformed edges directly from Z
Zp[:,t] = colxfm(Zp[:,t].T, Pr.T).T
Zp[t,:] = colxfm(Zp[t,:], Pr.T)


titles = ["Zp","Z","X"]
imgs = [Zp,Z,X]
fig, axs = plt.subplots(1, 3, figsize=(12, 4), #12 is width
                        gridspec_kw=dict(width_ratios=[img.shape[0] for img in imgs]))

for ax, img, title in zip(axs, imgs, titles):
    plot_image(img, ax=ax)
    ax.set(yticks=[], title=f'${title}$')

# compression_ratio_dict[N] = compression_ratio

max_abs_value = np.max(np.abs(X-Zp))

print(f"The maximum absolute value in the array is: {max_abs_value}")
# Out:
# The maximum absolute value in the array is: 7.247535904753022e-13
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 8.2 Quantisation and coding efficiency

# %% [markdown]
# The scaling factor `s` determines the degree of bi-orthogonality. If `s = 1` then Pf is the same
# as Pr, otherwise `1 < s < 2` weights the relative contributions of `Pf` and `Pr` un-equally.
#
# <div class="alert alert-block alert-danger">
#
# For an 8 × 8 DCT, try implementing an LBT with POT scaling factors varying from $1$
# to $2$ ($\sqrt{2}$ is often a good choice). In each case find the quantisation step which makes
# the rms error match the directly quantised image. Note the compression ratios and find
# the scaling factor which maximises these. Also note the visual features in these images.</div>

# %%
# your code here

N=8

Xq = quantise(X,17)
X_q_total_bits = bpp(quantise(X,17))*X.shape[0]*X.shape[1]

C8 = dct_ii(8)



decimal_range_stepsize = np.arange(20, 30, 0.1)

decimal_range_s = np.arange(1, 2, 0.01)

compression_ratio_dict = {}

optimal_s = -1
highest_compression = -1

for s in decimal_range_s:
    print("s: ",s)

# s=1

    Pf, Pr = pot_ii(N,s)

    t = np.s_[N//2:-N//2]  # N is the DCT size, I is the image size
    Xp = X.copy()  # copy the non-transformed edges directly from X
    Xp[t,:] = colxfm(Xp[t,:], Pf)
    Xp[:,t] = colxfm(Xp[:,t].T, Pf).T

    Y = colxfm(colxfm(Xp, C8).T, C8).T





    optimal_step = -1
    smallest_diff = 10e15

    def f(step_size):
        Y_q_test = quantise(Y,step_size)
        Z = colxfm(colxfm(Y_q_test.T, C8.T).T, C8.T)


        Zp = Z.copy()  #copy the non-transformed edges directly from Z
        Zp[:,t] = colxfm(Zp[:,t].T, Pr.T).T
        Zp[t,:] = colxfm(Zp[t,:], Pr.T)

        return abs(np.std(X-Xq)-np.std(X-Zp))


    for i in decimal_range_stepsize:
        # print(i,"             ",abs(f(i)))
        if f(i) < smallest_diff:
            smallest_diff = f(i)
            optimal_step = i

    print("optimal_step",optimal_step)
    Y_q = quantise(Y,optimal_step)


    Yr=regroup(Y_q, N)/N  #Yr is from quantised
    print("Total bits using dctbpp: {:,}".format(int(dctbpp(Yr, N))))


    compression_ratio = X_q_total_bits/(dctbpp(Yr,N)) #Yr is quantised. this is variable coding N=4 here
    print("compression ratio",compression_ratio)

    if compression_ratio > highest_compression:
        highest_compression = compression_ratio
        optimal_s = s

    Z = colxfm(colxfm(Y_q.T, C8.T).T, C8.T)
    # Z = colxfm(colxfm(Y.T, C8.T).T, C8.T) #dont quantise for now



    Zp = Z.copy()  #copy the non-transformed edges directly from Z
    Zp[:,t] = colxfm(Zp[:,t].T, Pr.T).T
    Zp[t,:] = colxfm(Zp[t,:], Pr.T)

    compression_ratio_dict[s] = compression_ratio


# titles = ["Zp","Z","X"]
# imgs = [Zp,Z,X]
# fig, axs = plt.subplots(1, 3, figsize=(12, 4), #12 is width
#                         gridspec_kw=dict(width_ratios=[img.shape[0] for img in imgs]))

# for ax, img, title in zip(axs, imgs, titles):
#     plot_image(img, ax=ax)
#     ax.set(yticks=[], title=f'${title}$')


# max_abs_value = np.max(np.abs(X-Zp))

# print(f"The maximum absolute value in the array is: {max_abs_value}")

# Sort the dictionary by key
sorted_keys = sorted(compression_ratio_dict.keys())

# Print the dictionary sorted by key
print("Compression ratio:")
for key in sorted_keys:
    print(f"{key}: {compression_ratio_dict[key]}")


print ("optimal s: ", optimal_s, ", compression ratio: ", compression_ratio_dict[optimal_s])


# TODO can plot compression ratio against s
# optimal s is sqrt 2 TODO fix. mine is 1.33
# my step size at s=1.41 matches sherry's stepsize 25.9
# Out:
# s:  1.0
# optimal_step 23.40000000000005
# Total bits using dctbpp: 75,446
# compression ratio 3.0235686718923427
# s:  1.01
# optimal_step 23.50000000000005
# Total bits using dctbpp: 75,257
# compression ratio 3.0311761531630386
# s:  1.02
# optimal_step 23.50000000000005
# Total bits using dctbpp: 75,298
# compression ratio 3.029532194056419
# s:  1.03
# optimal_step 23.60000000000005
# Total bits using dctbpp: 75,043
# compression ratio 3.039830961521025
# s:  1.04
# optimal_step 23.700000000000053
# Total bits using dctbpp: 74,855
# compression ratio 3.0474491915595165
# s:  1.05
# optimal_step 23.800000000000054
# Total bits using dctbpp: 74,649
# compression ratio 3.0558516644651372
# s:  1.06
# optimal_step 23.900000000000055
# Total bits using dctbpp: 74,431
# compression ratio 3.0648115295886234
# s:  1.07
# optimal_step 24.000000000000057
# Total bits using dctbpp: 74,311
# compression ratio 3.069751428012506
# s:  1.08
# optimal_step 24.10000000000006
# Total bits using dctbpp: 74,154
# compression ratio 3.076273733941936
# s:  1.09
# optimal_step 24.10000000000006
# Total bits using dctbpp: 74,219
# compression ratio 3.0735799531589274
# s:  1.1
# optimal_step 24.20000000000006
# Total bits using dctbpp: 74,030
# compression ratio 3.0814079062355906
# s:  1.11
# optimal_step 24.30000000000006
# Total bits using dctbpp: 73,863
# compression ratio 3.0883900386980656
# s:  1.12
# optimal_step 24.30000000000006
# Total bits using dctbpp: 73,917
# compression ratio 3.08611714870808
# s:  1.1300000000000001
# optimal_step 24.400000000000063
# Total bits using dctbpp: 73,733
# compression ratio 3.093824673055465
# s:  1.1400000000000001
# optimal_step 24.500000000000064
# Total bits using dctbpp: 73,542
# compression ratio 3.101876535633593
# s:  1.1500000000000001
# optimal_step 24.500000000000064
# Total bits using dctbpp: 73,630
# compression ratio 3.0981590939095303
# s:  1.1600000000000001
# optimal_step 24.600000000000065
# Total bits using dctbpp: 73,495
# compression ratio 3.1038358260804917
# s:  1.1700000000000002
# optimal_step 24.700000000000067
# Total bits using dctbpp: 73,356
# compression ratio 3.109728219285521
# s:  1.1800000000000002
# optimal_step 24.700000000000067
# Total bits using dctbpp: 73,490
# compression ratio 3.104064510179279
# s:  1.1900000000000002
# optimal_step 24.800000000000068
# Total bits using dctbpp: 73,274
# compression ratio 3.1132180700305607
# s:  1.2000000000000002
# optimal_step 24.90000000000007
# Total bits using dctbpp: 73,141
# compression ratio 3.1188901047600437
# s:  1.2100000000000002
# optimal_step 24.90000000000007
# Total bits using dctbpp: 73,214
# compression ratio 3.115766734298147
# s:  1.2200000000000002
# optimal_step 25.00000000000007
# Total bits using dctbpp: 73,089
# compression ratio 3.121105877496114
# s:  1.2300000000000002
# optimal_step 25.00000000000007
# Total bits using dctbpp: 73,166
# compression ratio 3.1178136564868133
# s:  1.2400000000000002
# optimal_step 25.100000000000072
# Total bits using dctbpp: 73,068
# compression ratio 3.1219887956559886
# s:  1.2500000000000002
# optimal_step 25.200000000000074
# Total bits using dctbpp: 72,925
# compression ratio 3.1281254567756918
# s:  1.2600000000000002
# optimal_step 25.200000000000074
# Total bits using dctbpp: 73,030
# compression ratio 3.1236098963429044
# s:  1.2700000000000002
# optimal_step 25.300000000000075
# Total bits using dctbpp: 72,879
# compression ratio 3.130095401359645
# s:  1.2800000000000002
# optimal_step 25.400000000000077
# Total bits using dctbpp: 72,758
# compression ratio 3.135308418285757
# s:  1.2900000000000003
# optimal_step 25.400000000000077
# Total bits using dctbpp: 72,834
# compression ratio 3.13199766811635
# s:  1.3000000000000003
# optimal_step 25.400000000000077
# Total bits using dctbpp: 72,907
# compression ratio 3.128879030380947
# s:  1.3100000000000003
# optimal_step 25.500000000000078
# Total bits using dctbpp: 72,737
# compression ratio 3.1362095190602677
# s:  1.3200000000000003
# optimal_step 25.500000000000078
# Total bits using dctbpp: 72,817
# compression ratio 3.1327421495843084
# s:  1.3300000000000003
# optimal_step 25.60000000000008
# Total bits using dctbpp: 72,661
# compression ratio 3.1394827296663514
# s:  1.3400000000000003
# optimal_step 25.60000000000008
# Total bits using dctbpp: 72,777
# compression ratio 3.134475398137807
# s:  1.3500000000000003
# optimal_step 25.70000000000008
# Total bits using dctbpp: 72,681
# compression ratio 3.138630144388883
# s:  1.3600000000000003
# optimal_step 25.70000000000008
# Total bits using dctbpp: 72,736
# compression ratio 3.136256758211467
# s:  1.3700000000000003
# optimal_step 25.70000000000008
# Total bits using dctbpp: 72,858
# compression ratio 3.131004919252782
# s:  1.3800000000000003
# optimal_step 25.800000000000082
# Total bits using dctbpp: 72,780
# compression ratio 3.1343612201014364
# s:  1.3900000000000003
# optimal_step 25.800000000000082
# Total bits using dctbpp: 72,879
# compression ratio 3.1300642318359357
# s:  1.4000000000000004
# optimal_step 25.900000000000084
# Total bits using dctbpp: 72,748
# compression ratio 3.1357242881649863
# s:  1.4100000000000004
# optimal_step 25.900000000000084
# Total bits using dctbpp: 72,847
# compression ratio 3.1314807103625397
# s:  1.4200000000000004
# optimal_step 26.000000000000085
# Total bits using dctbpp: 72,720
# compression ratio 3.13691368613949
# s:  1.4300000000000004
# optimal_step 26.000000000000085
# Total bits using dctbpp: 72,807
# compression ratio 3.1331829864463545
# s:  1.4400000000000004
# optimal_step 26.000000000000085
# Total bits using dctbpp: 72,904
# compression ratio 3.129004154611747
# s:  1.4500000000000004
# optimal_step 26.100000000000087
# Total bits using dctbpp: 72,796
# compression ratio 3.1336691839510475
# s:  1.4600000000000004
# optimal_step 26.100000000000087
# Total bits using dctbpp: 72,903
# compression ratio 3.129065204438291
# s:  1.4700000000000004
# optimal_step 26.100000000000087
# Total bits using dctbpp: 73,007
# compression ratio 3.1246032231879757
# s:  1.4800000000000004
# optimal_step 26.100000000000087
# Total bits using dctbpp: 73,083
# compression ratio 3.121346971662727
# s:  1.4900000000000004
# optimal_step 26.200000000000088
# Total bits using dctbpp: 73,021
# compression ratio 3.1239840611366216
# s:  1.5000000000000004
# optimal_step 26.200000000000088
# Total bits using dctbpp: 73,123
# compression ratio 3.1196228614343333
# s:  1.5100000000000005
# optimal_step 26.200000000000088
# Total bits using dctbpp: 73,220
# compression ratio 3.1154891642050644
# s:  1.5200000000000005
# optimal_step 26.30000000000009
# Total bits using dctbpp: 73,130
# compression ratio 3.119361016278036
# s:  1.5300000000000005
# optimal_step 26.30000000000009
# Total bits using dctbpp: 73,240
# compression ratio 3.1146421273876115
# s:  1.5400000000000005
# optimal_step 26.30000000000009
# Total bits using dctbpp: 73,336
# compression ratio 3.110580970644049
# s:  1.5500000000000005
# optimal_step 26.40000000000009
# Total bits using dctbpp: 73,254
# compression ratio 3.114044560465084
# s:  1.5600000000000005
# optimal_step 26.40000000000009
# Total bits using dctbpp: 73,410
# compression ratio 3.1074559472723076
# s:  1.5700000000000005
# optimal_step 26.40000000000009
# Total bits using dctbpp: 73,532
# compression ratio 3.102287641944451
# s:  1.5800000000000005
# optimal_step 26.40000000000009
# Total bits using dctbpp: 73,654
# compression ratio 3.0971420137125003
# s:  1.5900000000000005
# optimal_step 26.40000000000009
# Total bits using dctbpp: 73,798
# compression ratio 3.0911184776331986
# s:  1.6000000000000005
# optimal_step 26.40000000000009
# Total bits using dctbpp: 73,934
# compression ratio 3.0854190197458657
# s:  1.6100000000000005
# optimal_step 26.40000000000009
# Total bits using dctbpp: 74,018
# compression ratio 3.081934966975812
# s:  1.6200000000000006
# optimal_step 26.40000000000009
# Total bits using dctbpp: 74,157
# compression ratio 3.076133739663502
# s:  1.6300000000000006
# optimal_step 26.40000000000009
# Total bits using dctbpp: 74,282
# compression ratio 3.07096982044116
# s:  1.6400000000000006
# optimal_step 26.40000000000009
# Total bits using dctbpp: 74,436
# compression ratio 3.0646063166611888
# s:  1.6500000000000006
# optimal_step 26.40000000000009
# Total bits using dctbpp: 74,593
# compression ratio 3.058163617623632
# s:  1.6600000000000006
# optimal_step 26.40000000000009
# Total bits using dctbpp: 74,719
# compression ratio 3.0529929420348
# s:  1.6700000000000006
# optimal_step 26.40000000000009
# Total bits using dctbpp: 74,879
# compression ratio 3.046477594151184
# s:  1.6800000000000006
# optimal_step 26.500000000000092
# Total bits using dctbpp: 74,740
# compression ratio 3.0521464922637387
# s:  1.6900000000000006
# optimal_step 26.500000000000092
# Total bits using dctbpp: 74,925
# compression ratio 3.044609712336001
# s:  1.7000000000000006
# optimal_step 26.500000000000092
# Total bits using dctbpp: 75,094
# compression ratio 3.0377548228494393
# s:  1.7100000000000006
# optimal_step 26.500000000000092
# Total bits using dctbpp: 75,230
# compression ratio 3.032272833059381
# s:  1.7200000000000006
# optimal_step 26.500000000000092
# Total bits using dctbpp: 75,398
# compression ratio 3.0255071440580825
# s:  1.7300000000000006
# optimal_step 26.500000000000092
# Total bits using dctbpp: 75,585
# compression ratio 3.0180143797851615
# s:  1.7400000000000007
# optimal_step 26.500000000000092
# Total bits using dctbpp: 75,717
# compression ratio 3.012762455107102
# s:  1.7500000000000007
# optimal_step 26.500000000000092
# Total bits using dctbpp: 75,858
# compression ratio 3.0071461596294546
# s:  1.7600000000000007
# optimal_step 26.500000000000092
# Total bits using dctbpp: 76,006
# compression ratio 3.0013106577877777
# s:  1.7700000000000007
# optimal_step 26.500000000000092
# Total bits using dctbpp: 76,145
# compression ratio 2.9958396591520793
# s:  1.7800000000000007
# optimal_step 26.500000000000092
# Total bits using dctbpp: 76,253
# compression ratio 2.991579535195313
# s:  1.7900000000000007
# optimal_step 26.600000000000094
# Total bits using dctbpp: 76,195
# compression ratio 2.993862112695313
# s:  1.8000000000000007
# optimal_step 26.500000000000092
# Total bits using dctbpp: 76,522
# compression ratio 2.9810836948654207
# s:  1.8100000000000007
# optimal_step 26.500000000000092
# Total bits using dctbpp: 76,662
# compression ratio 2.975631938308249
# s:  1.8200000000000007
# optimal_step 26.500000000000092
# Total bits using dctbpp: 76,831
# compression ratio 2.9690732971942886
# s:  1.8300000000000007
# optimal_step 26.500000000000092
# Total bits using dctbpp: 76,979
# compression ratio 2.9633843845338546
# s:  1.8400000000000007
# optimal_step 26.600000000000094
# Total bits using dctbpp: 76,938
# compression ratio 2.9649507862956677
# s:  1.8500000000000008
# optimal_step 26.600000000000094
# Total bits using dctbpp: 77,085
# compression ratio 2.9593077203561338
# s:  1.8600000000000008
# optimal_step 26.600000000000094
# Total bits using dctbpp: 77,238
# compression ratio 2.953422108785415
# s:  1.8700000000000008
# optimal_step 26.600000000000094
# Total bits using dctbpp: 77,396
# compression ratio 2.9473925279503215
# s:  1.8800000000000008
# optimal_step 26.600000000000094
# Total bits using dctbpp: 77,549
# compression ratio 2.9416004716023125
# s:  1.8900000000000008
# optimal_step 26.500000000000092
# Total bits using dctbpp: 77,906
# compression ratio 2.928101158864713
# s:  1.9000000000000008
# optimal_step 26.500000000000092
# Total bits using dctbpp: 78,063
# compression ratio 2.922224555981787
# s:  1.9100000000000008
# optimal_step 26.500000000000092
# Total bits using dctbpp: 78,215
# compression ratio 2.9165512469377113
# s:  1.9200000000000008
# optimal_step 26.500000000000092
# Total bits using dctbpp: 78,380
# compression ratio 2.910403663545419
# s:  1.9300000000000008
# optimal_step 26.500000000000092
# Total bits using dctbpp: 78,558
# compression ratio 2.903804210654588
# s:  1.9400000000000008
# optimal_step 26.500000000000092
# Total bits using dctbpp: 78,699
# compression ratio 2.898612823920302
# s:  1.9500000000000008
# optimal_step 26.500000000000092
# Total bits using dctbpp: 78,843
# compression ratio 2.8933119625682586
# s:  1.9600000000000009
# optimal_step 26.500000000000092
# Total bits using dctbpp: 79,012
# compression ratio 2.8871425864125
# s:  1.9700000000000009
# optimal_step 26.500000000000092
# Total bits using dctbpp: 79,179
# compression ratio 2.881054440714715
# s:  1.9800000000000009
# optimal_step 26.500000000000092
# Total bits using dctbpp: 79,358
# compression ratio 2.874554534108009
# s:  1.9900000000000009
# optimal_step 26.500000000000092
# Total bits using dctbpp: 79,494
# compression ratio 2.8696318646073893
# Compression ratio:
# 1.0: 3.0235686718923427
# 1.01: 3.0311761531630386
# 1.02: 3.029532194056419
# 1.03: 3.039830961521025
# 1.04: 3.0474491915595165
# 1.05: 3.0558516644651372
# 1.06: 3.0648115295886234
# 1.07: 3.069751428012506
# 1.08: 3.076273733941936
# 1.09: 3.0735799531589274
# 1.1: 3.0814079062355906
# 1.11: 3.0883900386980656
# 1.12: 3.08611714870808
# 1.1300000000000001: 3.093824673055465
# 1.1400000000000001: 3.101876535633593
# 1.1500000000000001: 3.0981590939095303
# 1.1600000000000001: 3.1038358260804917
# 1.1700000000000002: 3.109728219285521
# 1.1800000000000002: 3.104064510179279
# 1.1900000000000002: 3.1132180700305607
# 1.2000000000000002: 3.1188901047600437
# 1.2100000000000002: 3.115766734298147
# 1.2200000000000002: 3.121105877496114
# 1.2300000000000002: 3.1178136564868133
# 1.2400000000000002: 3.1219887956559886
# 1.2500000000000002: 3.1281254567756918
# 1.2600000000000002: 3.1236098963429044
# 1.2700000000000002: 3.130095401359645
# 1.2800000000000002: 3.135308418285757
# 1.2900000000000003: 3.13199766811635
# 1.3000000000000003: 3.128879030380947
# 1.3100000000000003: 3.1362095190602677
# 1.3200000000000003: 3.1327421495843084
# 1.3300000000000003: 3.1394827296663514
# 1.3400000000000003: 3.134475398137807
# 1.3500000000000003: 3.138630144388883
# 1.3600000000000003: 3.136256758211467
# 1.3700000000000003: 3.131004919252782
# 1.3800000000000003: 3.1343612201014364
# 1.3900000000000003: 3.1300642318359357
# 1.4000000000000004: 3.1357242881649863
# 1.4100000000000004: 3.1314807103625397
# 1.4200000000000004: 3.13691368613949
# 1.4300000000000004: 3.1331829864463545
# 1.4400000000000004: 3.129004154611747
# 1.4500000000000004: 3.1336691839510475
# 1.4600000000000004: 3.129065204438291
# 1.4700000000000004: 3.1246032231879757
# 1.4800000000000004: 3.121346971662727
# 1.4900000000000004: 3.1239840611366216
# 1.5000000000000004: 3.1196228614343333
# 1.5100000000000005: 3.1154891642050644
# 1.5200000000000005: 3.119361016278036
# 1.5300000000000005: 3.1146421273876115
# 1.5400000000000005: 3.110580970644049
# 1.5500000000000005: 3.114044560465084
# 1.5600000000000005: 3.1074559472723076
# 1.5700000000000005: 3.102287641944451
# 1.5800000000000005: 3.0971420137125003
# 1.5900000000000005: 3.0911184776331986
# 1.6000000000000005: 3.0854190197458657
# 1.6100000000000005: 3.081934966975812
# 1.6200000000000006: 3.076133739663502
# 1.6300000000000006: 3.07096982044116
# 1.6400000000000006: 3.0646063166611888
# 1.6500000000000006: 3.058163617623632
# 1.6600000000000006: 3.0529929420348
# 1.6700000000000006: 3.046477594151184
# 1.6800000000000006: 3.0521464922637387
# 1.6900000000000006: 3.044609712336001
# 1.7000000000000006: 3.0377548228494393
# 1.7100000000000006: 3.032272833059381
# 1.7200000000000006: 3.0255071440580825
# 1.7300000000000006: 3.0180143797851615
# 1.7400000000000007: 3.012762455107102
# 1.7500000000000007: 3.0071461596294546
# 1.7600000000000007: 3.0013106577877777
# 1.7700000000000007: 2.9958396591520793
# 1.7800000000000007: 2.991579535195313
# 1.7900000000000007: 2.993862112695313
# 1.8000000000000007: 2.9810836948654207
# 1.8100000000000007: 2.975631938308249
# 1.8200000000000007: 2.9690732971942886
# 1.8300000000000007: 2.9633843845338546
# 1.8400000000000007: 2.9649507862956677
# 1.8500000000000008: 2.9593077203561338
# 1.8600000000000008: 2.953422108785415
# 1.8700000000000008: 2.9473925279503215
# 1.8800000000000008: 2.9416004716023125
# 1.8900000000000008: 2.928101158864713
# 1.9000000000000008: 2.922224555981787
# 1.9100000000000008: 2.9165512469377113
# 1.9200000000000008: 2.910403663545419
# 1.9300000000000008: 2.903804210654588
# 1.9400000000000008: 2.898612823920302
# 1.9500000000000008: 2.8933119625682586
# 1.9600000000000009: 2.8871425864125
# 1.9700000000000009: 2.881054440714715
# 1.9800000000000009: 2.874554534108009
# 1.9900000000000009: 2.8696318646073893
# optimal s:  1.3300000000000003 , compression ratio:  3.1394827296663514

# %% [markdown]
# The POT can often improve both compression and block smoothing, since the pre-filter
# acts to reduce correlations between each DCT sub-block, whilst the inverse post-filter
# acts to remove the discontinuities between sub-blocks. This is rather different from the
# operation of the DCT. Investigate this by looking at the basis functions, as you did with
# the DCT:

# %%
Pf, Pr = pot_ii(8)
bases = np.concatenate([np.full((8,1), np.nan), Pf, np.full((8,1), np.nan)], axis=1)
bases = bases.reshape(-1, 1)
fig, ax = plt.subplots()
im_obj = plot_image(bases @ bases.T, ax=ax)
fig.colorbar(im_obj, ax=ax);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# Look at both these bases and the pre-filtered image `Xp`, using different scaling factors
# `s`, and comment on the visual effect of varying these scaling factors. You may need to
# multiply `Xp` by up to 0.5 to display it better.</div>

# %%
# your code here

# %% [markdown]
# With this type of POT / DCT combination it is common to use smaller DCT block sizes
# but to code several blocks together. Hence a more accurate estimate of the number of bits
# is found by always using 16 × 16 blocks, i.e. regroup `Yq` with the correct size `N` to give
# `Yr`, but then always use `dctbpp(Yr, 16)`.
#
# <div class="alert alert-block alert-danger">
#
# Investigate the relative visual and compression performance of LBTs with 4 × 4, 8 × 8
# and 16 × 16 blocks, using the scaling factor you have previously selected. As before, be
# careful to match the rms error with a directly quantised image.</div>

# %%
# your code here
